# %% [markdown]
# ###Nama : Mathilda Hosiana Tambun
# ###Batch : 006 HCK

# %% [markdown]
# Latar belakang permasalahan, pada akhir tahun 2019 dunia sedang menghadapi masalah besar. Berawal dari munculnya suatu wabah penyakit yang disebabkan oleh virus corona atau yang akrab disebut Covid 19, hampir semua aspek kehidupan mengalami perubahan-perubahan yang semakin hari semakin mengkhawatirkan, mendebarkan seluruh isi dunia. Covid-19 telah menjadi perhatian publik sejak kemunculannya terdeteksi di Tiongkok di kota Wuhan Provinsi Hubei untuk kali pertama di awal tahun 2020. Meninggalnya ribuan jiwa akibat virus ini membuatnya menjadi pusat perhatian banyak negara, termasuk provinsi di beberapa negara sehingga WHO tanggal 11 Maret 2020 menetapkan wabah ini sebagai pandemi global. Analisa data covid 19 sanagat penting agar kita dapat melihat perkembangan setiap tahunnya agar menjadi referensi atau pembelajaran saat ada kasus yang sama sehingga dapat membandingkan data tiap tahun khususnya di tahun 2022 pada beberapa provinsi negara.

# %%
#Hal pertama yang dilakukan yaitu menginstall pandas
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# selain itu cara menginstal pandas bisa juga, python -m pip install pandas,  or conda install pandas

# %%
#Menggunakan AS dalam menyingkat penamaan numpy dan pandas 
import numpy as np
import pandas as pd

# %%
#Membaca dataset dengan format CSV 
df = pd.read_csv('https://raw.githubusercontent.com/Mathilda28/GC1/main/h8dsft_P0GC1_Mathilda.csv')

# %% [markdown]
# df merupakan variabel atau bisa juga untuk menampilkan dataset dan untuk read_csv akan menampilkan dataset yang akan di bantu oleh df. Karena data ini berbentuk csv jadi kita menggunakan read_csv tapi kalo formatnya berbentuk excel jadi pakenya pd.read_excel jadi bisa disesuaikan sama format data yang akan kita gunakan.

# %%
#Menampilkan seluruh dataset
df
# Out:
#         province_state  confirmed  deaths        date
# 0               Kansas        3.0     0.0  2020-05-15
# 1            Tennessee       88.0     0.0  2020-05-15
# 2              Georgia      695.0    23.0  2020-05-15
# 3             Nebraska        1.0     0.0  2020-05-15
# 4             Nebraska        8.0     0.0  2020-05-15
# ...                ...        ...     ...         ...
# 235706  South Carolina     8791.0   155.0  2022-09-11
# 235707    South Dakota     5076.0    63.0  2022-09-11
# 235708    South Dakota     3708.0    24.0  2022-09-11
# 235709    South Dakota     1000.0    16.0  2022-09-11
# 235710    South Dakota     1675.0    41.0  2022-09-11
#
# [235711 rows x 4 columns]

# %% [markdown]
# df sesuai fungsinya akan menampilkan semua dataset dimana terdapat kolom province_state, confirmed, deaths dan date. selain itu, kita bisa melihat index atau jumlah baris data tersebut sebannyak 235711 baris dan 4 kolom.

# %%
#Menampilkan 10 dataset teratas
df.head(10)
# Out:
#   province_state  confirmed  deaths        date
# 0         Kansas        3.0     0.0  2020-05-15
# 1      Tennessee       88.0     0.0  2020-05-15
# 2        Georgia      695.0    23.0  2020-05-15
# 3       Nebraska        1.0     0.0  2020-05-15
# 4       Nebraska        8.0     0.0  2020-05-15
# 5          Texas        2.0     0.0  2020-05-15
# 6       Illinois       30.0     4.0  2020-05-15
# 7      Tennessee        7.0     0.0  2020-05-15
# 8     Washington       21.0     0.0  2020-05-15
# 9       Michigan       14.0     2.0  2020-05-15

# %% [markdown]
# .head dapat menampilkan data teratas yang kita butuhkan, jadi saya memilih 10 dataset yang ingin saya tampilkan.

# %%
#Menampilkan data terbawah pada dataset
df.tail(10)
# Out:
#         province_state  confirmed  deaths        date
# 235701  South Carolina    16897.0   324.0  2022-09-11
# 235702  South Carolina    10066.0   164.0  2022-09-11
# 235703  South Carolina    18279.0   234.0  2022-09-11
# 235704  South Carolina   112096.0   901.0  2022-09-11
# 235705  South Carolina     2516.0    40.0  2022-09-11
# 235706  South Carolina     8791.0   155.0  2022-09-11
# 235707    South Dakota     5076.0    63.0  2022-09-11
# 235708    South Dakota     3708.0    24.0  2022-09-11
# 235709    South Dakota     1000.0    16.0  2022-09-11
# 235710    South Dakota     1675.0    41.0  2022-09-11

# %% [markdown]
# .tail menampilkan data terbawah dari dataset dan saya memilih melihat 10 data terbawah yaitu terlihat datanya pada tahun 2022

# %%
#Menampilkan Karakteristik Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235711 entries, 0 to 235710
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   province_state  225079 non-null  object
#  1   confirmed       235710 non-null  float64
#  2   deaths          235695 non-null  float64
#  3   date            235711 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 7.2+ MB

# %% [markdown]
# .info menmpilkan data dari jumlah baris 235711, kolom ada 4, tipe datanya ada object dan float64

# %%
#Tampilan Statistik Dasar 
df.describe()
# Out:
#           confirmed         deaths
# count  2.357100e+05  235695.000000
# mean   7.382595e+04    1024.125726
# std    5.863407e+05    6209.067622
# min    0.000000e+00       0.000000
# 25%    8.210000e+02      11.000000
# 50%    3.763000e+03      58.000000
# 75%    1.627300e+04     224.000000
# max    3.859118e+07  180570.000000

# %% [markdown]
# Pada penggunaan .describe kita dapat melihat hasil output yang dihasilkan berupa penjumlahan yang sama seperti saat kita menggunakan excel. Datanya berupa count dimana hasil dari jumlah keseluruhan yang terkena dampak covid sejumlah 235710 orang dan yang telah meninggal akibat dampak covid sebesar 235695. Karena .describe juga bisa menggunkan transpose kalo misalnya dataset memiliki jumlah kolom yang sangat banyak.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=235711, step=1)

# %% [markdown]
# .index ini akan menjelaskan kolomnya dari tabel tersebut mulai dari mana sampai mana

# %%
#Menampilkan query terhadap dataset
df
# Out:
#         province_state  confirmed  deaths        date
# 0               Kansas        3.0     0.0  2020-05-15
# 1            Tennessee       88.0     0.0  2020-05-15
# 2              Georgia      695.0    23.0  2020-05-15
# 3             Nebraska        1.0     0.0  2020-05-15
# 4             Nebraska        8.0     0.0  2020-05-15
# ...                ...        ...     ...         ...
# 235706  South Carolina     8791.0   155.0  2022-09-11
# 235707    South Dakota     5076.0    63.0  2022-09-11
# 235708    South Dakota     3708.0    24.0  2022-09-11
# 235709    South Dakota     1000.0    16.0  2022-09-11
# 235710    South Dakota     1675.0    41.0  2022-09-11
#
# [235711 rows x 4 columns]

# %% [markdown]
# df ini sama kayak df dengan data sebelumnya hanya untuk menampilkan data kembali dengan model 5 data teratas dan 5 data terbawah. Tapi di query kita membuat analisa dengan filter hanya di atas tahun 2021 saja

# %%
#Query Tahun
current_decade = df[df["date"] > '2021']

# %% [markdown]
# query tahun yang lebih dari 2021 saja menggunkan current_decade. jadi data yang akan terbaca atau kita olah nantinya itu tahun 2022

# %%
#Menampilkan khusus provinsi south dakota 
df[
    (df["province_state"] == "South Dakota") &
    (df ["confirmed"] > 100) &
    (df["deaths"] > 100) &
    (df["date"] > "2021-01-01") 
]
# Out:
#        province_state  confirmed  deaths        date
# 2013     South Dakota    10095.0   115.0  2022-02-16
# 2019     South Dakota    56573.0   489.0  2022-02-16
# 2575     South Dakota    13815.0   198.0  2021-05-26
# 4767     South Dakota    16028.0   102.0  2022-07-14
# 5330     South Dakota    16618.0   105.0  2022-10-03
# ...               ...        ...     ...         ...
# 225336   South Dakota    11718.0   142.0  2021-01-08
# 227535   South Dakota    31579.0   356.0  2021-05-12
# 229234   South Dakota    11205.0   124.0  2022-10-04
# 229236   South Dakota     9618.0   103.0  2022-10-04
# 231469   South Dakota    37885.0   369.0  2022-12-24
#
# [151 rows x 4 columns]

# %% [markdown]
# Menampilkan pada provinsi south dakota terkena covid 19 lebih dari 100 orang dan yang meninggal juga 100 orang pada tahun kedua covid 19 atau di tahun 2022

# %%
current_decade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178143 entries, 397 to 235710
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   province_state  170300 non-null  object
#  1   confirmed       178143 non-null  float64
#  2   deaths          178143 non-null  float64
#  3   date            178143 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 6.8+ MB

# %% [markdown]
# menampilkan informasi detail tentang dataframe, seperti jumlah baris data, nama-nama kolom berserta jumlah data dan tipe datanya, dan sebagainya. Pada tabelnya kita bisa melihat ada dua tipe data pada dataset yaitu float64 dan object

# %%
#Menampilkan Nilai Missing Values pada Dataset
df.isnull()
df.isna().sum()
# Out:
# province_state    10632
# confirmed             1
# deaths               16
# date                  0
# dtype: int64

# %% [markdown]
# Cara mencari missing values pada dataset ini bisa menggunakan df.isnull or df.isna itu sama saja tapi kalo mau liat secara keseluruhan bisa tambahin .sum jadinya kita bisa lihat pada setiap kolom yang missing values itu pada province_state sebanyak 10632, confirmed ada 1 dan deaths ada 16.

# %%
#Menangani Missing Value 
df.dropna()
# Out:
#         province_state  confirmed  deaths        date
# 0               Kansas        3.0     0.0  2020-05-15
# 1            Tennessee       88.0     0.0  2020-05-15
# 2              Georgia      695.0    23.0  2020-05-15
# 3             Nebraska        1.0     0.0  2020-05-15
# 4             Nebraska        8.0     0.0  2020-05-15
# ...                ...        ...     ...         ...
# 235706  South Carolina     8791.0   155.0  2022-09-11
# 235707    South Dakota     5076.0    63.0  2022-09-11
# 235708    South Dakota     3708.0    24.0  2022-09-11
# 235709    South Dakota     1000.0    16.0  2022-09-11
# 235710    South Dakota     1675.0    41.0  2022-09-11
#
# [225065 rows x 4 columns]

# %% [markdown]
# dengan cara menghapus, dengan di anggap tidak terdapat data pd kolom tsb

# %%
aa = df.dropna()

# %%
aa.isnull().sum()
# Out:
# province_state    0
# confirmed         0
# deaths            0
# date              0
# dtype: int64

# %%
aa.head()
# Out:
#   province_state  confirmed  deaths        date
# 0         Kansas        3.0     0.0  2020-05-15
# 1      Tennessee       88.0     0.0  2020-05-15
# 2        Georgia      695.0    23.0  2020-05-15
# 3       Nebraska        1.0     0.0  2020-05-15
# 4       Nebraska        8.0     0.0  2020-05-15

# %% [markdown]
# Memanggil kembali datasetnya

# %%
#Menampilkan Groupby
aa[
    (aa["confirmed"] > 20000000) &
    (aa["deaths"] > 20000) 
].groupby(["province_state", "date"])["deaths"].count()
# Out:
# province_state  date
# England         2022-10-10    1
#                 2022-12-12    1
#                 2022-12-20    1
# Name: deaths, dtype: int64

# %% [markdown]
# kesimpulannya adalah terdapat 3 data hasil filter dari confirmed

# %%
df[
    (df["province_state"] == "England" ) &
    (df["date"] > "2021-12-31")
] .groupby ("province_state") ["deaths"].sum()
# Out:
# province_state
# England    2290841.0
# Name: deaths, dtype: float64

# %% [markdown]
# Jadi kesimpulan pada data ini mau menampilkan bahwa di inggris pada tahun 2022 itu yang meninggal jumlahnya berapa sehingga hasilnya itu 2290841.0

# %%
#Memaggil kembali dataset dengan variabel aa untuk merubah nama kolom
aa
# Out:
#         province_state  confirmed  deaths        date
# 0               Kansas        3.0     0.0  2020-05-15
# 1            Tennessee       88.0     0.0  2020-05-15
# 2              Georgia      695.0    23.0  2020-05-15
# 3             Nebraska        1.0     0.0  2020-05-15
# 4             Nebraska        8.0     0.0  2020-05-15
# ...                ...        ...     ...         ...
# 235706  South Carolina     8791.0   155.0  2022-09-11
# 235707    South Dakota     5076.0    63.0  2022-09-11
# 235708    South Dakota     3708.0    24.0  2022-09-11
# 235709    South Dakota     1000.0    16.0  2022-09-11
# 235710    South Dakota     1675.0    41.0  2022-09-11
#
# [225065 rows x 4 columns]

# %% [markdown]
# Memanggil kembali datanya dengan nama variabel baru yaitu aa

# %%
#Merubah nama kolom 
renamed_aa = aa.rename(
    columns={"confirmed": "Positif_covid", }
)

renamed_aa.head()
# Out:
#   province_state  Positif_covid  deaths        date
# 0         Kansas            3.0     0.0  2020-05-15
# 1      Tennessee           88.0     0.0  2020-05-15
# 2        Georgia          695.0    23.0  2020-05-15
# 3       Nebraska            1.0     0.0  2020-05-15
# 4       Nebraska            8.0     0.0  2020-05-15

# %% [markdown]
# Jadi nama kolom sebelumnya confirmed yang artinya ini data menjelaskan setiap orang yang telah dinyatakan positif covid 19 dirubah menjadi nama kolom positif_covid

# %%
#Visualizing your pandas dataframe
# %matplotlib inline

# %% [markdown]
# %matplotlib inline adalah sebuah magic fuction di pyhton yang bila mau digunkan tidak perlu membuat import dan biasanya digunkan pada pandas untuk menampilkan visualisasi dalam bentuk grafik atau sebagainya

# %%
aa
# Out:
#         province_state  confirmed  deaths        date
# 0               Kansas        3.0     0.0  2020-05-15
# 1            Tennessee       88.0     0.0  2020-05-15
# 2              Georgia      695.0    23.0  2020-05-15
# 3             Nebraska        1.0     0.0  2020-05-15
# 4             Nebraska        8.0     0.0  2020-05-15
# ...                ...        ...     ...         ...
# 235706  South Carolina     8791.0   155.0  2022-09-11
# 235707    South Dakota     5076.0    63.0  2022-09-11
# 235708    South Dakota     3708.0    24.0  2022-09-11
# 235709    South Dakota     1000.0    16.0  2022-09-11
# 235710    South Dakota     1675.0    41.0  2022-09-11
#
# [225065 rows x 4 columns]

# %%
aa[aa["province_state"] == "South Dakota"].groupby("date")["deaths"].sum().plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Mulai dari tahun 2020 bulan maret terjadi awal mula kasus covid-19 muncul di provinsi south dakota kemudian terjadi lonjakan angka kematian kasus covid-19 di sekitar bulan maret menuju awal april tahun 2022, angka kematiannya melonjak lebih dari 1200 kasus kematian covid-19, juga terjadi penurunan signifikan kasus kematian covid-19 di provinsi south dakota pada akhir bulan mei sampai awal bulan juni. Ternyata pada bulan agustus terjadi lonjakan kembali yang hampir menyerupai tingkat lonjakan di bulan maret menuju april tahun 2022, di awal tahun 2023 pada pertengahan bulan januari kasus kematian covid-19 di provinsi south dakota mencapai angka 820.

# %%
#You can also create other types of plots, like a bar plot:
aa[aa["province_state"] == "South Dakota"].value_counts().head(4).plot(kind="bar")
# Out:
# <Axes: xlabel='province_state,confirmed,deaths,date'>
